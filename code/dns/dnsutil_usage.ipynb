# %%
import numpy as np
import pandas as pd
import re
import os
import time
import sys
import csv
from imp import reload

# %%
import dnsutil

# %%
#
# Load the merged dataset csv
#
df = pd.read_csv('../data/2018-10-06/merged.csv')
# Out:
# /Users/nscsekhar/anaconda/envs/w266/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(10)
# Out:
#                    domain malware        date  dga
# 0             netflix.com     NaN  2018-10-06    0
# 1  api-global.netflix.com     NaN  2018-10-06    0
# 2        prod.netflix.com     NaN  2018-10-06    0
# 3   push.prod.netflix.com     NaN  2018-10-06    0
# 4              google.com     NaN  2018-10-06    0
# 5          www.google.com     NaN  2018-10-06    0
# 6           microsoft.com     NaN  2018-10-06    0
# 7         doubleclick.net     NaN  2018-10-06    0
# 8            facebook.com     NaN  2018-10-06    0
# 9     ichnaea.netflix.com     NaN  2018-10-06    0

# %%
urls = df.head(100)['domain']

# %%
reload(dnsutil)
urls_ips = dnsutil.lookup_urls(urls)
# Out:
# netflix.com : 52.37.219.6
# api-global.netflix.com : 54.152.88.53
# Failed to find IP for : prod.netflix.com
# push.prod.netflix.com : 34.205.5.168
# google.com : 216.58.195.238
# www.google.com : 216.58.195.228
# microsoft.com : 104.40.211.35
# doubleclick.net : 172.217.164.110
# facebook.com : 157.240.22.35
# ichnaea.netflix.com : 34.194.110.235
# Failed to find IP for : g.doubleclick.net
# safebrowsing.googleapis.com : 172.217.164.106
# googleads.g.doubleclick.net : 172.217.5.98
# clients4.google.com : 172.217.164.110
# google-analytics.com : 172.217.164.100
# data.microsoft.com : 40.112.143.140
# www.googleapis.com : 172.217.6.74
# live.com : 204.79.197.212
# apple.com : 17.178.96.59
# nrdp50-appboot.netflix.com : 52.4.114.194
# clientservices.googleapis.com : 216.58.195.227
# youtube.com : 172.217.164.110
# www.google-analytics.com : 172.217.164.110
# settings-win.data.microsoft.com : 40.124.45.19
# amazonaws.com : 207.171.166.22
# secure.netflix.com : 23.7.179.237
# ...

# %%
urls_ips
# Out:
# [('netflix.com', '52.37.219.6'),
#  ('api-global.netflix.com', '54.152.88.53'),
#  ('push.prod.netflix.com', '34.205.5.168'),
#  ('google.com', '216.58.195.238'),
#  ('www.google.com', '216.58.195.228'),
#  ('microsoft.com', '104.40.211.35'),
#  ('doubleclick.net', '172.217.164.110'),
#  ('facebook.com', '157.240.22.35'),
#  ('ichnaea.netflix.com', '34.194.110.235'),
#  ('safebrowsing.googleapis.com', '172.217.164.106'),
#  ('googleads.g.doubleclick.net', '172.217.5.98'),
#  ('clients4.google.com', '172.217.164.110'),
#  ('google-analytics.com', '172.217.164.100'),
#  ('data.microsoft.com', '40.112.143.140'),
#  ('www.googleapis.com', '172.217.6.74'),
#  ('live.com', '204.79.197.212'),
#  ('apple.com', '17.178.96.59'),
#  ('nrdp50-appboot.netflix.com', '52.4.114.194'),
#  ('clientservices.googleapis.com', '216.58.195.227'),
#  ('youtube.com', '172.217.164.110'),
#  ('www.google-analytics.com', '172.217.164.110'),
#  ('settings-win.data.microsoft.com', '40.124.45.19'),
# ...

# %%
with open('../data/2018-10-06/domains_to_ips.csv', 'w') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(urls_ips)

writeFile.close()
